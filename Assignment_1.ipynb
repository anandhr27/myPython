# %%
# Question: 1

aList = [100, 200, 300, 400, 500]

print("Reverse Order using slicing method is:", aList[::-1])
aList.reverse()
print("Reverse Order using in-build method is:", aList)
# Out:
# Reverse Order using slicing method is: [500, 400, 300, 200, 100]
# Reverse Order using in-build method is: [500, 400, 300, 200, 100]

# %%
# Question: 2

List1 = [10, 20, 30]
List2 = [100, 200, 300]

print("List1 \t List2")
for x, y in zip(List1, List2):
    print(x, "\t", y)
# Out:
# List1 	 List2
# 10 	 100
# 20 	 200
# 30 	 300

# %%
# Question: 3

List1 = ["a", "b", ["c", "d", ["e","f"],"g","h"],"I","j"]
subList = [1,2,3]

# for item, x in enumerate(List1):
#     print(item, x)

# Output:
# 0 a
# 1 b
# 2 ['c', 'd', ['e', 'f'], 'g', 'h']
# 3 I
# 4 j

"""
# Program for Output:1 
# get the 2nd elements in List1
"""
element_2 = List1[2]

print("2nd element of List1 =: ", element_2)

element_2[2].extend(subList)
print("2nd element after extend subList: ",element_2)

List1[2] = element_2

print("Output of List1 after extend: ", List1)

"""
# Program for Output:2 
# get the 2nd elements in List1
"""
List1 = ["a", "b", ["c", "d", ["e","f"],"g","h"],"I","j"]
subList = [1,2,3]
element_2 = List1[2]

print("2nd element of List1 =: ", element_2)

element_2[2].append(subList)
print("2nd element after append subList: ",element_2)

List1[2] = element_2

print("Output of List1 after append: ", List1)
# Out:
# 2nd element of List1 =:  ['c', 'd', ['e', 'f'], 'g', 'h']
# 2nd element after extend subList:  ['c', 'd', ['e', 'f', 1, 2, 3], 'g', 'h']
# Output of List1 after extend:  ['a', 'b', ['c', 'd', ['e', 'f', 1, 2, 3], 'g', 'h'], 'I', 'j']
# 2nd element of List1 =:  ['c', 'd', ['e', 'f'], 'g', 'h']
# 2nd element after append subList:  ['c', 'd', ['e', 'f', [1, 2, 3]], 'g', 'h']
# Output of List1 after append:  ['a', 'b', ['c', 'd', ['e', 'f', [1, 2, 3]], 'g', 'h'], 'I', 'j']

# %%
# Another simple method for the above question:

List1 = ["a", "b", ["c", "d", ["e","f"],"g","h"],"I","j"]
subList = [1,2,3]

List1[2][2].extend(subList)
print("List1 after extend method: ", List1)

List1 = ["a", "b", ["c", "d", ["e","f"],"g","h"],"I","j"]
List1[2][2].append(subList)
print("List1 after append method: ", List1)
# Out:
# List1 after extend method:  ['a', 'b', ['c', 'd', ['e', 'f', 1, 2, 3], 'g', 'h'], 'I', 'j']
# List1 after append method:  ['a', 'b', ['c', 'd', ['e', 'f', [1, 2, 3]], 'g', 'h'], 'I', 'j']

# %%
# Question: 4

print("Using For Loop")
for item in range(1, 6):
    print(item, end=" ")

print("\n")

print("Using While Loop")
number = 1
while number <=5:
    print(number, end =" ")
    number += 1

print("\n")
# Out:
# Using For Loop
# 1 2 3 4 5
#
# Using While Loop
# 1 2 3 4 5

# %%
# Question: 5

def myFun(name, age):
    print(name, age)

myFun("Python", 25)
# Out:
# Python 25
